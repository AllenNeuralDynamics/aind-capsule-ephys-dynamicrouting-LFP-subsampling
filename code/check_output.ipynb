# %%
import zarr
import utils
import pathlib
import spikeinterface as si
import matplotlib.pyplot as plt
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# /opt/conda/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)

# %%
TEMPORAL_FACTOR = 2
SPATIAL_FACTOR = 4

# %%
raw_probe_recording = si.read_zarr('/root/capsule/data/ecephys_674562_2023-10-05_12-13-56/ecephys_compressed/experiment1_Record Node 102#Neuropix-PXI-100.ProbeA-LFP.zarr')
subsampled_probe_lfp_times = zarr.open('/root/capsule/data/ecephys_674562_2023-10-05_LFP_Test/ecephys_674562_2023-10-05_12-13-56_ProbeA-LFP/ProbeA-LFP_lfp_timestamps.zarr', mode='r')

# %%
plt.plot(raw_times)
plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
utils.plot_raw_and_subsampled_lfp(pathlib.Path('/root/capsule/data/ecephys_674562_2023-10-05_LFP_Test/ecephys_674562_2023-10-05_12-13-56_ProbeA-LFP/ProbeA-LFP_lfp_subsampled.zarr'),
                                   pathlib.Path('/root/capsule/data/ecephys_674562_2023-10-05_LFP_Test/ecephys_674562_2023-10-05_12-13-56_ProbeA-LFP/ProbeA-LFP_lfp_subsampled.zarr'),
                                   raw_times, subsampled_probe_lfp_times, TEMPORAL_FACTOR, SPATIAL_FACTOR)
